# %%
data={
     'A':[1,2,3,4],
     'B':['a','b','a','d'],
     'C':[2,3,4,5],
     'D':['rob','alfa','rob','beta']
     }

import pandas as pd
df=pd.DataFrame(data)
df
# Out:
#    A  B  C     D
# 0  1  a  2   rob
# 1  2  b  3  alfa
# 2  3  a  4   rob
# 3  4  d  5  beta

# %%
df.loc[(df.B=='a')&(df.D=='rob'),'A']=df['C']*5
df
# Out:
#     A  B  C     D
# 0  10  a  2   rob
# 1   2  b  3  alfa
# 2  20  a  4   rob
# 3   4  d  5  beta
